# %% [markdown]
# # GSR, HR and ET emotion detector

# %% [markdown]
# ## Data import and preparation

# %% [markdown]
# ## GSR

# %% [markdown]
# ## HR

# %% [markdown]
# ## ET

# %% [markdown]
# ## Decision Making

# %% [markdown]
# ## Data export
